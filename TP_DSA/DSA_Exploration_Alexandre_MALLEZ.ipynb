# %% [markdown]
# <center><h1>Lab: Exploring the DSA Transparency database</h1></center>
#
# The goal of this lab is to study, with very simple methods, a sample from the [Digital Services Act Transparency Database](https://transparency.dsa.ec.europa.eu/dashboard). The database collects moderation decision by online platforms (VLOPs, Very Large Online Platforms), as identified by the [DSA](https://eur-lex.europa.eu/legal-content/EN/TXT/HTML/?uri=CELEX%3A32022R2065#enc_1) and the European Commission.
#
# The main goal of the lab is to gain insights on the differentiated moderation practices of social media platforms subject to the DSA's obligations. To do this, we us a stratified sample of the transparency database, filtered to contain 70000 decisions by social media platforms.

# %% [markdown]
# ## Imports

# %%
import numpy
import pandas as pd

# %% [markdown]
# ## Load data

# %%
data = pd.read_csv(open("./sample-strat-may2024-socmed-70k.csv", encoding="utf-8"), sep=",")

# %% [markdown]
# ## Basic data exploration
#
# The first goal is to get a hang of the data that you have, its variables, and answer a few basic questions. You can familirise yourself with the variables by reading the document "DSA transparency database - Description of variables.docx" provided.
#
# - Which are the platforms in the sample?
# - How many decisions are present for each platform?
# - Which variables would you modify, and how (this might include removing variables, changing their type, creating new variables from a combination of existing ones, etc.)?
#
# Write your thoughts and summarised results here.

# %%
data["platform_name"].value_counts()
# Out:
# platform_name
# Facebook     10000
# TikTok       10000
# Instagram    10000
# Snapchat     10000
# LinkedIn     10000
# X            10000
# YouTube      10000
# Name: count, dtype: int64

# %% [markdown]
# -platforms are : Facebook, Tik Tok, Instagram, Snapchat, LinkedIn, X, Youtube
# -There are 10000 decisions for each platform
# -most of these variables are usefull but some others are not ('platform_uid'). Or some like 'incompatible_content_illegal' could be change (it is open but should be multiple choice). Besides all the date are not really usefull (application_date , content_date, created_date) and could be regrouped with only the difference between these date, it's the same for end date restriction, most of the time all the restriction ended at the same time and the information of what restriction is given and is already sufficient ( 'end_date_visibility_restriction', 'end_date_monetary_restriction', 'end_date_service_restriction','end_date_account_restriction').

# %% [markdown]
# In general, you can see a variable `x` by typing `data["x"]`, see the different values the variable takes with `set(data["x"].values)`, and see the counts of values for a variable using `data["x"].value_counts()`.

# %%
data["decision_visibility"]
# Out:
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4        ["DECISION_VISIBILITY_CONTENT_REMOVED"]
#                           ...
# 69995    ["DECISION_VISIBILITY_CONTENT_REMOVED"]
# 69996    ["DECISION_VISIBILITY_CONTENT_REMOVED"]
# 69997    ["DECISION_VISIBILITY_CONTENT_REMOVED"]
# 69998    ["DECISION_VISIBILITY_CONTENT_REMOVED"]
# 69999    ["DECISION_VISIBILITY_CONTENT_REMOVED"]
# Name: decision_visibility, Length: 70000, dtype: object

# %% [markdown]
# Already you should be able to remove of modify a few variables. Do so before going on, to facilitate your exploration. You can remove a column with `data = data.drop("platform_name", axis=1)`.

# %%
data.drop("decision_visibility", axis=1)
data.drop("source_identity", axis=1)
data.drop("source_type", axis=1)
data.drop("application_date", axis=1)
data.drop("source_identity", axis=1)
# Out:
#                            decision_visibility  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4      ["DECISION_VISIBILITY_CONTENT_REMOVED"]
# ...                                        ...
# 69995  ["DECISION_VISIBILITY_CONTENT_REMOVED"]
# 69996  ["DECISION_VISIBILITY_CONTENT_REMOVED"]
# 69997  ["DECISION_VISIBILITY_CONTENT_REMOVED"]
# 69998  ["DECISION_VISIBILITY_CONTENT_REMOVED"]
# 69999  ["DECISION_VISIBILITY_CONTENT_REMOVED"]
#
#                             decision_ground illegal_content_legal_ground  \
# 0      DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
# 1      DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
# 2      DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
# 3      DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
# 4      DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
# ...                                     ...                          ...
# 69995  DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
# 69996  DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
# 69997  DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
# 69998  DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
# 69999  DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
#
#                              incompatible_content_ground  \
# 0      This was a violation of "sections 3.2" of our ...
# 1      This was a violation of "sections 3.2" of our ...
# 2      This was a violation of "sections 3.2" of our ...
# 3      This was a violation of "sections 3.2" of our ...
# 4      This was a violation of "sections 3.2" of our ...
# ...                                                  ...
# 69995                           Destination requirements
# 69996                           Destination requirements
# 69997                             Technical requirements
# 69998                             Abusing the ad network
# 69999                           Destination requirements
#
#                                            category  \
# 0      STATEMENT_CATEGORY_SCOPE_OF_PLATFORM_SERVICE
# 1      STATEMENT_CATEGORY_SCOPE_OF_PLATFORM_SERVICE
# 2      STATEMENT_CATEGORY_SCOPE_OF_PLATFORM_SERVICE
# 3      STATEMENT_CATEGORY_SCOPE_OF_PLATFORM_SERVICE
# 4      STATEMENT_CATEGORY_SCOPE_OF_PLATFORM_SERVICE
# ...                                             ...
# 69995  STATEMENT_CATEGORY_SCOPE_OF_PLATFORM_SERVICE
# 69996  STATEMENT_CATEGORY_SCOPE_OF_PLATFORM_SERVICE
# 69997  STATEMENT_CATEGORY_SCOPE_OF_PLATFORM_SERVICE
# 69998            STATEMENT_CATEGORY_SCAMS_AND_FRAUD
# 69999  STATEMENT_CATEGORY_SCOPE_OF_PLATFORM_SERVICE
#
#                            content_type         content_date  \
# 0                ["CONTENT_TYPE_OTHER"]  2024-05-05 00:00:00
# 1                ["CONTENT_TYPE_OTHER"]  2024-05-11 00:00:00
# 2                ["CONTENT_TYPE_OTHER"]  2024-05-05 00:00:00
# 3                ["CONTENT_TYPE_OTHER"]  2024-05-08 00:00:00
# 4      ["CONTENT_TYPE_SYNTHETIC_MEDIA"]  2024-05-11 00:00:00
# ...                                 ...                  ...
# 69995            ["CONTENT_TYPE_OTHER"]  2024-03-05 00:00:00
# 69996            ["CONTENT_TYPE_OTHER"]  2024-04-22 00:00:00
# 69997            ["CONTENT_TYPE_OTHER"]  2023-10-17 00:00:00
# 69998            ["CONTENT_TYPE_OTHER"]  2023-08-18 00:00:00
# 69999            ["CONTENT_TYPE_OTHER"]  2023-11-03 00:00:00
#
#                                        territorial_scope     application_date  \
# 0      ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...  2024-05-05 00:00:00
# 1      ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...  2024-05-11 00:00:00
# 2      ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...  2024-05-05 00:00:00
# 3      ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...  2024-05-08 00:00:00
# 4      ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...  2024-05-11 00:00:00
# ...                                                  ...                  ...
# 69995  ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...  2024-05-07 00:00:00
# 69996  ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...  2024-05-05 00:00:00
# 69997  ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...  2024-05-06 00:00:00
# 69998  ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...  2024-05-07 00:00:00
# 69999  ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...  2024-05-06 00:00:00
#
#             source_type automated_detection                automated_decision  \
# 0      SOURCE_VOLUNTARY                 Yes      AUTOMATED_DECISION_PARTIALLY
# 1      SOURCE_VOLUNTARY                 Yes      AUTOMATED_DECISION_PARTIALLY
# 2      SOURCE_VOLUNTARY                 Yes      AUTOMATED_DECISION_PARTIALLY
# 3      SOURCE_VOLUNTARY                 Yes      AUTOMATED_DECISION_PARTIALLY
# 4      SOURCE_VOLUNTARY                 Yes      AUTOMATED_DECISION_PARTIALLY
# ...                 ...                 ...                               ...
# 69995  SOURCE_VOLUNTARY                 Yes          AUTOMATED_DECISION_FULLY
# 69996  SOURCE_VOLUNTARY                 Yes          AUTOMATED_DECISION_FULLY
# 69997  SOURCE_VOLUNTARY                 Yes          AUTOMATED_DECISION_FULLY
# 69998  SOURCE_VOLUNTARY                 Yes  AUTOMATED_DECISION_NOT_AUTOMATED
# 69999  SOURCE_VOLUNTARY                 Yes          AUTOMATED_DECISION_FULLY
#
#       platform_name           created_at
# 0          Facebook  2024-05-06 14:40:11
# 1          Facebook  2024-05-12 13:42:48
# 2          Facebook  2024-05-06 11:51:21
# 3          Facebook  2024-05-09 14:40:45
# 4          Facebook  2024-05-12 16:34:10
# ...             ...                  ...
# 69995       YouTube  2024-05-08 22:51:13
# 69996       YouTube  2024-05-06 23:23:28
# 69997       YouTube  2024-05-07 22:30:52
# 69998       YouTube  2024-05-08 22:31:53
# 69999       YouTube  2024-05-07 22:31:11
#
# [70000 rows x 14 columns]

# %% [markdown]
# ## Filtering by platform
#
# Now that we have a general idea of the database, we would like to get a first idea of differentiated behaviours by platform. You can filter a dataframe like so: `data[data["x"]==y]`. Below, for example, is the code to get all decisions for TikTok.

# %%
data[data["platform_name"] == "TikTok"]
# Out:
#                            decision_visibility  \
# 10000  ["DECISION_VISIBILITY_CONTENT_REMOVED"]
# 10001            ["DECISION_VISIBILITY_OTHER"]
# 10002            ["DECISION_VISIBILITY_OTHER"]
# 10003            ["DECISION_VISIBILITY_OTHER"]
# 10004            ["DECISION_VISIBILITY_OTHER"]
# ...                                        ...
# 19995            ["DECISION_VISIBILITY_OTHER"]
# 19996  ["DECISION_VISIBILITY_CONTENT_REMOVED"]
# 19997            ["DECISION_VISIBILITY_OTHER"]
# 19998  ["DECISION_VISIBILITY_CONTENT_REMOVED"]
# 19999                                      NaN
#
#                             decision_ground illegal_content_legal_ground  \
# 10000  DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
# 10001  DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
# 10002  DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
# 10003  DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
# 10004  DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
# ...                                     ...                          ...
# 19995  DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
# 19996  DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
# 19997  DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
# 19998  DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
# 19999  DECISION_GROUND_INCOMPATIBLE_CONTENT                          NaN
#
#                              incompatible_content_ground  \
# 10000                  Hate Speech and Hateful Behaviors
# 10001                               Community Guidelines
# 10002  The ad features restricted or prohibited claim...
# 10003                               Community Guidelines
# 10004                               Community Guidelines
# ...                                                  ...
# 19995                               Community Guidelines
# 19996                               Community Guidelines
# 19997                               Community Guidelines
# 19998                                       Animal Abuse
# 19999                       Advertising policy violation
#
#                                            category            content_type  \
# 10000  STATEMENT_CATEGORY_ILLEGAL_OR_HARMFUL_SPEECH   ["CONTENT_TYPE_TEXT"]
# 10001  STATEMENT_CATEGORY_SCOPE_OF_PLATFORM_SERVICE  ["CONTENT_TYPE_VIDEO"]
# 10002  STATEMENT_CATEGORY_SCOPE_OF_PLATFORM_SERVICE  ["CONTENT_TYPE_VIDEO"]
# 10003  STATEMENT_CATEGORY_SCOPE_OF_PLATFORM_SERVICE  ["CONTENT_TYPE_VIDEO"]
# 10004  STATEMENT_CATEGORY_SCOPE_OF_PLATFORM_SERVICE  ["CONTENT_TYPE_VIDEO"]
# ...                                             ...                     ...
# 19995  STATEMENT_CATEGORY_SCOPE_OF_PLATFORM_SERVICE  ["CONTENT_TYPE_VIDEO"]
# 19996  STATEMENT_CATEGORY_SCOPE_OF_PLATFORM_SERVICE  ["CONTENT_TYPE_IMAGE"]
# 19997  STATEMENT_CATEGORY_SCOPE_OF_PLATFORM_SERVICE  ["CONTENT_TYPE_VIDEO"]
# 19998             STATEMENT_CATEGORY_ANIMAL_WELFARE   ["CONTENT_TYPE_TEXT"]
# 19999  STATEMENT_CATEGORY_SCOPE_OF_PLATFORM_SERVICE  ["CONTENT_TYPE_OTHER"]
#
#               content_date                                  territorial_scope  \
# 10000  2024-05-07 00:00:00  ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...
# 10001  2024-05-09 00:00:00  ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...
# 10002  2024-05-08 00:00:00                                             ["PL"]
# 10003  2024-05-09 00:00:00  ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...
# 10004  2024-05-09 00:00:00  ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...
# ...                    ...                                                ...
# 19995  2024-05-09 00:00:00  ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...
# 19996  2024-04-18 00:00:00  ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...
# 19997  2024-05-09 00:00:00  ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...
# 19998  2024-05-08 00:00:00  ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...
# 19999  2023-01-12 00:00:00  ["AT","BE","BG","CY","CZ","DE","DK","EE","ES",...
#
#           application_date       source_type  source_identity  \
# 10000  2024-05-07 00:00:00  SOURCE_VOLUNTARY              NaN
# 10001  2024-05-09 00:00:00  SOURCE_VOLUNTARY              NaN
# 10002  2024-05-09 00:00:00  SOURCE_VOLUNTARY              NaN
# 10003  2024-05-09 00:00:00  SOURCE_VOLUNTARY              NaN
# 10004  2024-05-09 00:00:00  SOURCE_VOLUNTARY              NaN
# ...                    ...               ...              ...
# 19995  2024-05-09 00:00:00  SOURCE_VOLUNTARY              NaN
# 19996  2024-05-06 00:00:00  SOURCE_VOLUNTARY              NaN
# 19997  2024-05-09 00:00:00  SOURCE_VOLUNTARY              NaN
# 19998  2024-05-08 00:00:00  SOURCE_VOLUNTARY              NaN
# 19999  2024-05-06 00:00:00  SOURCE_VOLUNTARY              NaN
#
#       automated_detection                automated_decision platform_name  \
# 10000                 Yes          AUTOMATED_DECISION_FULLY        TikTok
# 10001                 Yes          AUTOMATED_DECISION_FULLY        TikTok
# 10002                 Yes  AUTOMATED_DECISION_NOT_AUTOMATED        TikTok
# 10003                 Yes          AUTOMATED_DECISION_FULLY        TikTok
# 10004                 Yes          AUTOMATED_DECISION_FULLY        TikTok
# ...                   ...                               ...           ...
# 19995                 Yes          AUTOMATED_DECISION_FULLY        TikTok
# 19996                 Yes          AUTOMATED_DECISION_FULLY        TikTok
# 19997                 Yes          AUTOMATED_DECISION_FULLY        TikTok
# 19998                 Yes          AUTOMATED_DECISION_FULLY        TikTok
# 19999                 Yes          AUTOMATED_DECISION_FULLY        TikTok
#
#                 created_at
# 10000  2024-05-07 23:10:14
# 10001  2024-05-09 02:58:51
# 10002  2024-05-10 05:49:37
# 10003  2024-05-09 19:31:33
# 10004  2024-05-10 11:18:20
# ...                    ...
# 19995  2024-05-10 10:15:31
# 19996  2024-05-06 04:47:09
# 19997  2024-05-11 14:11:54
# 19998  2024-05-08 21:09:20
# 19999  2024-05-06 14:15:15
#
# [10000 rows x 15 columns]

# %%
automatic_detection_counts = data.groupby(["platform_name", "automated_detection"]).size().unstack()
print(automatic_detection_counts)
automated_decision_counts = data.groupby(["platform_name", "automated_decision"]).size()
print(automated_decision_counts)
# Out:
# automated_detection       No     Yes
# platform_name
# Facebook               129.0  9871.0
# Instagram              521.0  9479.0
# LinkedIn               307.0  9693.0
# Snapchat              7672.0  2328.0
# TikTok                 316.0  9684.0
# X                    10000.0     NaN
# YouTube               1159.0  8841.0
# platform_name  automated_decision
# Facebook       AUTOMATED_DECISION_NOT_AUTOMATED      129
#                AUTOMATED_DECISION_PARTIALLY         9871
# Instagram      AUTOMATED_DECISION_NOT_AUTOMATED      521
#                AUTOMATED_DECISION_PARTIALLY         9479
# LinkedIn       AUTOMATED_DECISION_FULLY              962
#                AUTOMATED_DECISION_NOT_AUTOMATED     9038
# Snapchat       AUTOMATED_DECISION_FULLY             2811
#                AUTOMATED_DECISION_NOT_AUTOMATED     7189
# TikTok         AUTOMATED_DECISION_FULLY             9378
#                AUTOMATED_DECISION_NOT_AUTOMATED      622
# X              AUTOMATED_DECISION_NOT_AUTOMATED    10000
# YouTube        AUTOMATED_DECISION_FULLY             4942
#                AUTOMATED_DECISION_NOT_AUTOMATED     4357
#                AUTOMATED_DECISION_PARTIALLY          701
# dtype: int64

# %% [markdown]
# Perform a variable exploration per platform. What can you infer in terms of differentiated moderation practices?

# %% [markdown]
# We observe that there are a different moderation pratices for each platforms : for instance X don't have any automated detection, Facebook has a very large part of atomated detection in which decision are partially automated made (it is kinda the same for Instagramm), Linkedin in spite of having a large part of automated detection still have most of the decision made manually... We can  see with these datas that moderation practices are very different between all these different platforms.

# %% [markdown]
# ## Cross-frequency counts
#
# In the next steps, we are interested in going a bit deeper, seeing how variables relate to each other. This can be done with a cross-frequency analysis, _i.e._ looking how variables co-occur together. Below is an example:

# %%
data.groupby("platform_name")["decision_ground"].value_counts()
# Out:
# platform_name  decision_ground
# Facebook       DECISION_GROUND_INCOMPATIBLE_CONTENT    10000
# Instagram      DECISION_GROUND_INCOMPATIBLE_CONTENT     9999
#                DECISION_GROUND_ILLEGAL_CONTENT             1
# LinkedIn       DECISION_GROUND_INCOMPATIBLE_CONTENT    10000
# Snapchat       DECISION_GROUND_INCOMPATIBLE_CONTENT     9993
#                DECISION_GROUND_ILLEGAL_CONTENT             7
# TikTok         DECISION_GROUND_INCOMPATIBLE_CONTENT    10000
# X              DECISION_GROUND_ILLEGAL_CONTENT         10000
# YouTube        DECISION_GROUND_INCOMPATIBLE_CONTENT     9957
#                DECISION_GROUND_ILLEGAL_CONTENT            43
# Name: count, dtype: int64

# %% [markdown]
# What can you tell, by platform, reading this kind of analysis?

# %% [markdown]
# For Facebook, Instagram, LinkedIn, Snapchat, TikTok and Youtube: these platforms heavily emphasize enforcing internal platform policies (DECISION_GROUND_INCOMPATIBLE_CONTENT), with little or no focus on illegal content. X deals only with illegal content (DECISION_GROUND_ILLEGAL_CONTENT) suggesting an emphasis on addressing legal obligations over internal policy enforcement.

# %% [markdown]
# ## Moderation time
#
# Create a new variable for moderation time, _i.e._ the time between the decision and its application. Is this new variable relevant? What can you conclude from it?

# %%
# Create the moderation_time variable

data['moderation_time'] = (data['application_date'] - data['content_date']).dt.total_seconds() / 3600

average_moderation_time = data.groupby("platform_name")["moderation_time"].mean()

print(average_moderation_time)
# Out:
# platform_name
# Facebook     1798.1856
# Instagram    2476.9512
# LinkedIn      304.4256
# Snapchat     6370.4712
# TikTok        270.9648
# X               0.0000
# YouTube      9609.8304
# Name: moderation_time, dtype: float64

# %% [markdown]
# Moderation times vary significantly across platforms. TikTok is extremely fast (271 sec), likely due to full automation, while YouTube is much slower (9609 sec), possibly because of high content volume and manual reviews. X is instant (0 sec) zhich indicate full automated decision (or these are false data). LinkedIn is surprisingly quick (304 sec) despite mostly manual decisions, suggesting an efficient process. Overall, automation often speeds up moderation but it varies depending on the platform (maybe for Linkedin it's different since the context of the platform is different, there are less moderation needed,they are more distributed)
